# %%
import requests
import pandas as pd

# %%
response = requests.get("https://randomuser.me/api/")

# %%
response
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# {'ID': 'cb090040-17c4-4f16-aa60-d1882c21dde9', 'Message': '', 'Global': {'NewConfirmed': 210413, 'TotalConfirmed': 668454123, 'NewDeaths': 1586, 'TotalDeaths': 6747898, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z'}, 'Countries': [{'ID': 'd71c39e7-76dd-43d3-90c9-39b7298054f9', 'Country': 'Afghanistan', 'CountryCode': 'AF', 'Slug': 'afghanistan', 'NewConfirmed': 43, 'TotalConfirmed': 208545, 'NewDeaths': 3, 'TotalDeaths': 7882, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': 'e69188a8-3c0d-4414-8805-0963d08b81c1', 'Country': 'Albania', 'CountryCode': 'AL', 'Slug': 'albania', 'NewConfirmed': 10, 'TotalConfirmed': 334167, 'NewDeaths': 0, 'TotalDeaths': 3596, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': '757ae08f-23d0-4c39-bbf2-f5693b60ce1d', 'Country': 'Algeria', 'CountryCode': 'DZ', 'Slug': 'algeria', 'NewConfirmed': 2, 'TotalConfirmed': 271378, 'NewDeaths': 0, 'TotalDeaths': 6881, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': 'fab05bf5-d9e5-4e71-8c45-3f90ffcfd12d', 'Country': 'Andorra', 'CountryCode': 'AD', 'Slug': 'andorra', 'NewConfirmed': 0, 'TotalConfirmed': 47839, 'NewDeaths': 0, 'TotalDeaths': 165, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': 'e3c286b7-3023-43e1-a1bf-02102dc3af1f', 'Country': 'Angola', 'CountryCode': 'AO', 'Slug': 'angola', 'NewConfirmed': 0, 'TotalConfirmed': 105184, 'NewDeaths': 0, 'TotalDeaths': 1931, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': '2a859bbd-5fb3-4a3f-9c3f-4dcc857ef273', 'Country': 'Antarctica', 'CountryCode': 'AQ', 'Slug': 'antarctica', 'NewConfirmed': 0, 'TotalConfirmed': 11, 'NewDeaths': 0, 'TotalDeaths': 0, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': '4c6b31b3-9b8d-4f86-8611-c9b06fe5a250', 'Country': 'Antigua and Barbuda', 'CountryCode': 'AG', 'Slug': 'antigua-and-barbuda', 'NewConfirmed': 0, 'TotalConfirmed': 9106, 'NewDeaths': 0, 'TotalDeaths': 146, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': 'f4c54b9f-b940-4e6d-b43b-6c438cfa2466', 'Country': 'Argentina', 'CountryCode': 'AR', 'Slug': 'argentina', 'NewConfirmed': 0, 'TotalConfirmed': 10037135, 'NewDeaths': 0, 'TotalDeaths': 130421, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': 'f3490240-982c-44f2-9f8d-acf61fc95d99', 'Country': 'Armenia', 'CountryCode': 'AM', 'Slug': 'armenia', 'NewConfirmed': 0, 'TotalConfirmed': 446008, 'NewDeaths': 0, 'TotalDeaths': 8717, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': '2641ec32-553e-4d42-a5ec-2225d93e4fe6', 'Country': 'Australia', 'CountryCode': 'AU', 'Slug': 'australia', 'NewConfirmed': 0, 'TotalConfirmed': 11295446, 'NewDeaths': 0, 'TotalDeaths': 18615, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': 'c23d9e9d-f27a-4094-be22-5803f604b14b', 'Country': 'Austria', 'CountryCode': 'AT', 'Slug': 'austria', 'NewConfirmed': 3482, 'TotalConfirmed': 5780229, 'NewDeaths': 27, 'TotalDeaths': 21689, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': 'a3f0df3f-f785-45bf-92ec-88e793b92272', 'Country': 'Azerbaijan', 'CountryCode': 'AZ', 'Slug': 'azerbaijan', 'NewConfirmed': 35, 'TotalConfirmed': 827944, 'NewDeaths': 4, 'TotalDeaths': 10085, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': '95667a14-c37c-4e7d-a056-8885933ae8a6', 'Country': 'Bahamas', 'CountryCode': 'BS', 'Slug': 'bahamas', 'NewConfirmed': 0, 'TotalConfirmed': 37491, 'NewDeaths': 0, 'TotalDeaths': 833, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2023-02-02T12:39:30.535Z', 'Premium': {}}, {'ID': ' ...

# %%
df = pd.DataFrame(response)

# %%
print(response.content[1:10])
# Out:
# b'"results"'

# %%
response = requests.get('https://api.thedogapi.com/v1/breeds')
response
response.reason
# Out:
# 'OK'

# %%
response = requests.get('https://api.covid19api.com/summary')
response
# Out:
# <Response [200]>

# %%
json = response.json()
json
# Out:
# {'ID': 'cb090040-17c4-4f16-aa60-d1882c21dde9',
#  'Message': '',
#  'Global': {'NewConfirmed': 210413,
#   'TotalConfirmed': 668454123,
#   'NewDeaths': 1586,
#   'TotalDeaths': 6747898,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z'},
#  'Countries': [{'ID': 'd71c39e7-76dd-43d3-90c9-39b7298054f9',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 43,
#    'TotalConfirmed': 208545,
#    'NewDeaths': 3,
#    'TotalDeaths': 7882,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e69188a8-3c0d-4414-8805-0963d08b81c1',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 334167,
#    'NewDeaths': 0,
#    'TotalDeaths': 3596,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '757ae08f-23d0-4c39-bbf2-f5693b60ce1d',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 271378,
#    'NewDeaths': 0,
#    'TotalDeaths': 6881,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'fab05bf5-d9e5-4e71-8c45-3f90ffcfd12d',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 47839,
#    'NewDeaths': 0,
#    'TotalDeaths': 165,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e3c286b7-3023-43e1-a1bf-02102dc3af1f',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 105184,
#    'NewDeaths': 0,
#    'TotalDeaths': 1931,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '2a859bbd-5fb3-4a3f-9c3f-4dcc857ef273',
#    'Country': 'Antarctica',
#    'CountryCode': 'AQ',
#    'Slug': 'antarctica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '4c6b31b3-9b8d-4f86-8611-c9b06fe5a250',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9106,
#    'NewDeaths': 0,
#    'TotalDeaths': 146,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f4c54b9f-b940-4e6d-b43b-6c438cfa2466',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10037135,
#    'NewDeaths': 0,
#    'TotalDeaths': 130421,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f3490240-982c-44f2-9f8d-acf61fc95d99',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 446008,
#    'NewDeaths': 0,
#    'TotalDeaths': 8717,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '2641ec32-553e-4d42-a5ec-2225d93e4fe6',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11295446,
#    'NewDeaths': 0,
#    'TotalDeaths': 18615,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'c23d9e9d-f27a-4094-be22-5803f604b14b',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 3482,
#    'TotalConfirmed': 5780229,
#    'NewDeaths': 27,
#    'TotalDeaths': 21689,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'a3f0df3f-f785-45bf-92ec-88e793b92272',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 35,
#    'TotalConfirmed': 827944,
#    'NewDeaths': 4,
#    'TotalDeaths': 10085,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '95667a14-c37c-4e7d-a056-8885933ae8a6',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 37491,
#    'NewDeaths': 0,
#    'TotalDeaths': 833,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'ef4f6daf-336d-4e84-876c-cd72611e014e',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 700452,
#    'NewDeaths': 0,
#    'TotalDeaths': 1543,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '5303b137-1d06-4d7d-8897-84a5e6b22754',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 2037556,
#    'NewDeaths': 0,
#    'TotalDeaths': 29442,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9514ba09-e2c5-4d10-bd3b-d31adb3984ea',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 106157,
#    'NewDeaths': 0,
#    'TotalDeaths': 571,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'ce0ff53b-8245-4615-ae15-a4171c560559',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 994037,
#    'NewDeaths': 0,
#    'TotalDeaths': 7118,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'a7b86d4c-776b-4142-a242-649096eb3d1d',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4691499,
#    'NewDeaths': 0,
#    'TotalDeaths': 33557,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '087a7794-fa62-4bb3-a7b0-a85e0161ebd0',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 70660,
#    'NewDeaths': 0,
#    'TotalDeaths': 688,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'b279b956-140c-4a7a-a786-bc02b32a3a31',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27989,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'd73c1c87-7950-417b-8d89-4cf7c36277c6',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 62605,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '28f95dc3-b29b-4fe2-ab82-59d8090a29d4',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 301,
#    'TotalConfirmed': 1187986,
#    'NewDeaths': 1,
#    'TotalDeaths': 22346,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '25729c10-1d63-4f64-a76f-59d8a8bde1f2',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 401384,
#    'NewDeaths': 1,
#    'TotalDeaths': 16255,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '4aab15ef-4a09-44c4-800e-2a184d0cbde5',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 329227,
#    'NewDeaths': 0,
#    'TotalDeaths': 2800,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '63961099-2f60-4716-816a-9199a0e65ba3',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 16766,
#    'TotalConfirmed': 36824580,
#    'NewDeaths': 182,
#    'TotalDeaths': 697074,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7348350a-b9c4-4c2b-8b81-8e51ef4dea66',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 847,
#    'TotalConfirmed': 276067,
#    'NewDeaths': 0,
#    'TotalDeaths': 225,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '222033bb-6fcb-40be-befd-e37fce8393cc',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 60,
#    'TotalConfirmed': 1295426,
#    'NewDeaths': 0,
#    'TotalDeaths': 38179,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7753e8de-2ca1-4f01-bc78-19675edd02f6',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22025,
#    'NewDeaths': 0,
#    'TotalDeaths': 396,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '2bb6dd69-331e-42bf-9a53-4c3705e5c662',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 53355,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '1e3b9da8-a80b-4d51-a5c0-0247182117cc',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 138693,
#    'NewDeaths': 0,
#    'TotalDeaths': 3056,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e69b5674-a3bf-4190-af8e-e65cdf5111dc',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 123993,
#    'NewDeaths': 0,
#    'TotalDeaths': 1965,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '79e07de0-11d2-4517-b488-96f39ff3a25f',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 924,
#    'TotalConfirmed': 3937494,
#    'NewDeaths': 20,
#    'TotalDeaths': 45095,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7e47d484-f2a6-426c-b752-8998843da58f',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63229,
#    'NewDeaths': 0,
#    'TotalDeaths': 413,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9fa92d53-60ad-4122-89eb-fdd09ef7638c',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 15368,
#    'NewDeaths': 0,
#    'TotalDeaths': 113,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '572c3cae-d4e1-4440-b1fb-c255cd49cc77',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7652,
#    'NewDeaths': 0,
#    'TotalDeaths': 194,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '3c27f8f8-3d3a-486a-b8ef-9f622c88fb21',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 1029,
#    'TotalConfirmed': 5118981,
#    'NewDeaths': 6,
#    'TotalDeaths': 63812,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'b29cb984-f5ea-48a4-ab52-6c8c2d632433',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 3381681,
#    'NewDeaths': 0,
#    'TotalDeaths': 18726,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '8a717f7f-9558-487f-9928-219a1a9a6524',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6352923,
#    'NewDeaths': 0,
#    'TotalDeaths': 142186,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '1d3c6725-3207-4cfc-8400-ef01666302a9',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8992,
#    'NewDeaths': 0,
#    'TotalDeaths': 161,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'adc1fd4b-4139-4b7b-8212-7538f66eab33',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25375,
#    'NewDeaths': 0,
#    'TotalDeaths': 388,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '3185e238-e128-4111-a979-0b796ffb2541',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 95514,
#    'NewDeaths': 0,
#    'TotalDeaths': 1463,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'cd041f65-4021-406f-9cee-51c5106bc773',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 3805,
#    'TotalConfirmed': 1186176,
#    'NewDeaths': 16,
#    'TotalDeaths': 9158,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'de9be235-706b-4d07-a301-edca3a83c50d',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 56,
#    'TotalConfirmed': 1267580,
#    'NewDeaths': 6,
#    'TotalDeaths': 17877,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9cb8ee00-ca5e-4f32-bb52-5a31c3a41bbe',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 1112438,
#    'NewDeaths': 0,
#    'TotalDeaths': 8530,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'bd710b88-0fb5-4060-b950-f3a70d582959',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 642663,
#    'NewDeaths': 0,
#    'TotalDeaths': 1287,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '53f2d09a-7f9c-4e86-93bc-98d22b42eb6c',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 663,
#    'TotalConfirmed': 4589483,
#    'NewDeaths': 3,
#    'TotalDeaths': 42307,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'cb9dd293-5f51-4ce3-9ec2-2599bc1c2dc6',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 87982,
#    'NewDeaths': 0,
#    'TotalDeaths': 833,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'dee105b8-5a16-4633-baf4-2c9f6d70f86e',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 204,
#    'TotalConfirmed': 3446409,
#    'NewDeaths': 7,
#    'TotalDeaths': 8194,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'd4eed420-1297-4110-8ab8-edfc54247314',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15690,
#    'NewDeaths': 0,
#    'TotalDeaths': 189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e0baf955-3f3e-4a49-b83d-f448efc8c647',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15760,
#    'NewDeaths': 0,
#    'TotalDeaths': 74,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7e6f49d0-9b12-450c-9c85-0115940948ee',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 660095,
#    'NewDeaths': 0,
#    'TotalDeaths': 4384,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '47499672-64d6-4ae0-9d87-6e1b5413383a',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1051239,
#    'NewDeaths': 0,
#    'TotalDeaths': 35942,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'bd2cea1c-f4f7-49b4-925b-82ae7936e33e',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 515645,
#    'NewDeaths': 0,
#    'TotalDeaths': 24805,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e382022e-07c2-47a2-bf22-a745bfbe16f3',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 201785,
#    'NewDeaths': 0,
#    'TotalDeaths': 4230,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '103e80ca-e1e8-4e56-b213-6c0a2b664128',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17190,
#    'NewDeaths': 0,
#    'TotalDeaths': 183,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'fbe84416-d0a6-4214-8c25-be2578ec1059',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10189,
#    'NewDeaths': 0,
#    'TotalDeaths': 103,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9881eb48-a82a-469e-b4e4-acebc7188fd9',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 372,
#    'TotalConfirmed': 613903,
#    'NewDeaths': 8,
#    'TotalDeaths': 2912,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '771dc6c8-f7cb-4228-9f90-27fbfb233dd2',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 38,
#    'TotalConfirmed': 499531,
#    'NewDeaths': 0,
#    'TotalDeaths': 7572,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'd42ccf52-2a6b-40ef-aebc-f13621deddec',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 68820,
#    'NewDeaths': 0,
#    'TotalDeaths': 883,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'c94fa5f1-ca35-4353-89b6-6591c338550d',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1458619,
#    'NewDeaths': 0,
#    'TotalDeaths': 8639,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '68a49909-0a9a-4f73-87a5-c0db0a9b4a06',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 6860,
#    'TotalConfirmed': 39729161,
#    'NewDeaths': 57,
#    'TotalDeaths': 165274,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '48b4f426-51e3-460b-88fc-6fb251915668',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 48981,
#    'NewDeaths': 0,
#    'TotalDeaths': 306,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '08a38938-9a8e-48f9-9ca8-63bd3c9cba8f',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12586,
#    'NewDeaths': 0,
#    'TotalDeaths': 372,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e80faf66-8519-4baf-9952-976040989f15',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1814180,
#    'NewDeaths': 0,
#    'TotalDeaths': 16926,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9d9ebed4-40c7-4bb8-8f8a-b2202a1db96d',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 21060,
#    'TotalConfirmed': 37779833,
#    'NewDeaths': 148,
#    'TotalDeaths': 165711,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '62a3a697-0b97-4e27-925b-50532add47c1',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 171112,
#    'NewDeaths': 0,
#    'TotalDeaths': 1462,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e4121fc9-bb8e-408a-a012-3e5b5e053fa3',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5548487,
#    'NewDeaths': 0,
#    'TotalDeaths': 34779,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '6f088953-dff8-4ddd-a08c-22448a3f3d10',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19680,
#    'NewDeaths': 0,
#    'TotalDeaths': 238,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '967b39f7-af5d-49d2-8c24-d347f960061c',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 811,
#    'TotalConfirmed': 1227853,
#    'NewDeaths': 5,
#    'TotalDeaths': 20106,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f567b26e-c69b-45d5-bd0a-f1dda4402a35',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 38240,
#    'NewDeaths': 0,
#    'TotalDeaths': 467,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '3440e9ff-7283-4392-96e0-6ea5ee97abef',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8947,
#    'NewDeaths': 0,
#    'TotalDeaths': 176,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'ca385344-86fb-4c8f-818c-af7e46d4cbf9',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 28,
#    'TotalConfirmed': 72950,
#    'NewDeaths': 0,
#    'TotalDeaths': 1294,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '24ea5aed-4f67-41a3-ae5f-52cdf60e1cdc',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 68,
#    'TotalConfirmed': 34076,
#    'NewDeaths': 0,
#    'TotalDeaths': 860,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'ff3e17bd-d730-4249-9850-c5f1ea04bbcb',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'b17cde61-6b0e-4ea5-b39f-40f0ca52b315',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 420,
#    'TotalConfirmed': 470757,
#    'NewDeaths': 2,
#    'TotalDeaths': 11104,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '661e1ba6-d6dd-4467-9f6c-69d074ef08d8',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2191827,
#    'NewDeaths': 0,
#    'TotalDeaths': 48658,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'cad9637f-b737-4ed4-a96a-6eed70a0ef7c',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 83,
#    'TotalConfirmed': 208688,
#    'NewDeaths': 0,
#    'TotalDeaths': 199,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '36d8d417-75b6-4d38-848b-9a51c12fc518',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 111,
#    'TotalConfirmed': 44684120,
#    'NewDeaths': 0,
#    'TotalDeaths': 530740,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'c708a8d7-cd81-46d4-a724-364b8fb11493',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 260,
#    'TotalConfirmed': 6730016,
#    'NewDeaths': 4,
#    'TotalDeaths': 160814,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'c1102996-3364-4bc8-b6d8-86ea710dd8c5',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 98,
#    'TotalConfirmed': 7564350,
#    'NewDeaths': 2,
#    'TotalDeaths': 144749,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '01034fbf-a69f-4980-8b16-4b6ab74fb5fa',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2465545,
#    'NewDeaths': 0,
#    'TotalDeaths': 25375,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'b415bb39-ee37-464b-a7d2-31019039c841',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1700253,
#    'NewDeaths': 0,
#    'TotalDeaths': 8462,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9c584508-412d-4e69-8840-33656eadabd3',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 872,
#    'TotalConfirmed': 4786180,
#    'NewDeaths': 16,
#    'TotalDeaths': 12193,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '5c6f19f0-8ae2-413f-bcdd-c618a3e1acd3',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25453789,
#    'NewDeaths': 0,
#    'TotalDeaths': 186833,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7a5f8eb3-ed13-47a6-b06f-cf00266071fb',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 153407,
#    'NewDeaths': 0,
#    'TotalDeaths': 3480,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f5f9fcbe-384a-4044-acc0-2eaffcff0585',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 47118,
#    'TotalConfirmed': 32555047,
#    'NewDeaths': 246,
#    'TotalDeaths': 68099,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '15b16dd5-1175-42a3-8200-1a7e0c94ef88',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1746997,
#    'NewDeaths': 0,
#    'TotalDeaths': 14122,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'bd68d8c5-3611-4a01-8a65-9aee5316096e',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1496549,
#    'NewDeaths': 0,
#    'TotalDeaths': 19065,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'd53f2c97-1d0d-4ab6-a600-8484d3712dcf',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 342810,
#    'NewDeaths': 0,
#    'TotalDeaths': 5688,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '541a1f43-7416-4805-b2a9-20f04882007f',
#    'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5008,
#    'NewDeaths': 0,
#    'TotalDeaths': 18,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '48c42e57-1b00-4c82-8121-5b44c93d974e',
#    'Country': 'Korea (North)',
#    'CountryCode': 'KP',
#    'Slug': 'korea-north',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '0ce20f0d-5c05-4d8a-a054-924438264c15',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 20420,
#    'TotalConfirmed': 30197066,
#    'NewDeaths': 42,
#    'TotalDeaths': 33486,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '26d71cf3-f6ef-4143-8bb4-61d3dd962d87',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 662858,
#    'NewDeaths': 0,
#    'TotalDeaths': 2570,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f9a79894-e754-4c75-9e8f-b2a9b3aacdca',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 206592,
#    'NewDeaths': 0,
#    'TotalDeaths': 2991,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '32dbb548-674e-4ba8-a6ba-6cccf3e64d3f',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 217973,
#    'NewDeaths': 0,
#    'TotalDeaths': 758,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '8d37853f-c9c9-450d-932a-2852d14a35e3',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 975282,
#    'NewDeaths': 0,
#    'TotalDeaths': 6214,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '8b33b322-3d12-4db6-96ec-4f4cdb4b32dd',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 135,
#    'TotalConfirmed': 1228639,
#    'NewDeaths': 2,
#    'TotalDeaths': 10790,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'c83e97f5-0358-4957-902c-9b40d2a7de53',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 34790,
#    'NewDeaths': 0,
#    'TotalDeaths': 723,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '0051513b-8162-457b-8291-710e736376e8',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 8062,
#    'NewDeaths': 0,
#    'TotalDeaths': 294,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'fa5ae427-43d1-4da9-8a4a-470417127c90',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 507162,
#    'NewDeaths': 0,
#    'TotalDeaths': 6437,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '04cdd42f-f619-4b7f-af43-a04d2b61c977',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21349,
#    'NewDeaths': 0,
#    'TotalDeaths': 89,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'fbd7e4b4-10e1-46de-84b1-ac24fbdbcec3',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 535,
#    'TotalConfirmed': 1296493,
#    'NewDeaths': 1,
#    'TotalDeaths': 9541,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e85b5c34-7f79-4792-a4f6-9147d919ee35',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 92,
#    'TotalConfirmed': 314731,
#    'NewDeaths': 3,
#    'TotalDeaths': 1210,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '671ac061-6ac4-4856-8f91-ae3b33a6ae6e',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 346428,
#    'NewDeaths': 0,
#    'TotalDeaths': 9638,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'c58d615d-e37e-4e73-ad88-8df787da8a46',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 67827,
#    'NewDeaths': 0,
#    'TotalDeaths': 1419,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'be5caaaf-c3fa-41d4-9fcd-c55a09cdedc3',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 54,
#    'TotalConfirmed': 88559,
#    'NewDeaths': 0,
#    'TotalDeaths': 2686,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7f0d7ce4-6029-4232-bed8-ee334967cdcd',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 251,
#    'TotalConfirmed': 5036593,
#    'NewDeaths': 0,
#    'TotalDeaths': 36942,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '0c8f4d0a-fbee-404e-a0fc-bb24c94a3f6a',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 185715,
#    'NewDeaths': 0,
#    'TotalDeaths': 311,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'cce30a5e-282d-4336-9a84-d092bf44c6ae',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 32783,
#    'NewDeaths': 0,
#    'TotalDeaths': 743,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '063a644e-c68e-43d9-88ad-2b73c655bae1',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 109,
#    'TotalConfirmed': 117062,
#    'NewDeaths': 0,
#    'TotalDeaths': 824,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '689ad444-c6d9-45e5-b616-552d2272bb20',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15584,
#    'NewDeaths': 0,
#    'TotalDeaths': 17,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '0edccd18-f09d-4793-8db9-799691931106',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 63665,
#    'NewDeaths': 0,
#    'TotalDeaths': 997,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '756ed661-ae8d-4fdd-ae34-72a969a2d3fa',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 294602,
#    'NewDeaths': 0,
#    'TotalDeaths': 1043,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '2c6671ff-731e-4f85-aba9-55c828cb46b6',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 540,
#    'TotalConfirmed': 7368252,
#    'NewDeaths': 8,
#    'TotalDeaths': 332198,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'fa182f1b-28bc-40de-97b8-75210334a634',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22676,
#    'NewDeaths': 0,
#    'TotalDeaths': 58,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '3d571c4b-e976-4a15-83e7-afd36a58db27',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 600,
#    'TotalConfirmed': 598673,
#    'NewDeaths': 3,
#    'TotalDeaths': 11953,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9f140380-e99b-4481-ae59-73d0027fec62',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 16063,
#    'NewDeaths': 0,
#    'TotalDeaths': 65,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '2a47b350-1837-49ab-863c-4fddd17ab736',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 1007871,
#    'NewDeaths': 0,
#    'TotalDeaths': 2136,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'ded0d051-fd8f-429f-9692-25173bfc7866',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 60,
#    'TotalConfirmed': 286355,
#    'NewDeaths': 0,
#    'TotalDeaths': 2797,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '05ae1657-1d87-4fcb-bab2-1fbf254f3898',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 1272240,
#    'NewDeaths': 0,
#    'TotalDeaths': 16296,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '083687a5-d652-434b-8344-a65f02de80bb',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 231994,
#    'NewDeaths': 0,
#    'TotalDeaths': 2233,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '67d3e173-b254-4ba1-afcb-945051b4f87f',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 633820,
#    'NewDeaths': 0,
#    'TotalDeaths': 19490,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '0bf4f53f-7178-471d-a4df-e4539ec2d70a',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 170741,
#    'NewDeaths': 0,
#    'TotalDeaths': 4088,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '092340ad-ac66-421e-bfbe-f55ca541258a',
#    'Country': 'Nauru',
#    'CountryCode': 'NR',
#    'Slug': 'nauru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4621,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '29cc9d4d-1b42-45a4-b865-55d9540528c7',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1001100,
#    'NewDeaths': 0,
#    'TotalDeaths': 12020,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '3380ad33-3e08-4083-b924-13350a16491f',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 1079,
#    'TotalConfirmed': 8582361,
#    'NewDeaths': 0,
#    'TotalDeaths': 22990,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'ddd9284b-0b33-4faa-9db7-5cb1a5e5ae7f',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2190095,
#    'NewDeaths': 0,
#    'TotalDeaths': 2479,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'fc0a4657-fe3d-450e-9e95-48a97425c0bd',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15569,
#    'NewDeaths': 0,
#    'TotalDeaths': 245,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'abd3cb22-af19-42de-a7ca-9d584b38090b',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9508,
#    'NewDeaths': 0,
#    'TotalDeaths': 315,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'd79a967c-bebd-44bf-bcd1-537177020082',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 266463,
#    'NewDeaths': 0,
#    'TotalDeaths': 3155,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'a3927215-6561-4954-a32b-c6d379caa210',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 72,
#    'TotalConfirmed': 1477856,
#    'NewDeaths': 0,
#    'TotalDeaths': 5112,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f92575b1-4caa-444f-9158-9c81e4948006',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 399449,
#    'NewDeaths': 0,
#    'TotalDeaths': 4628,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e29ea8d7-417d-4285-b429-f623177e06a4',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 1576312,
#    'NewDeaths': 0,
#    'TotalDeaths': 30640,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '927e75e3-dc7e-4bf9-a392-26a416b7d72d',
#    'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5986,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '16520d41-e693-48a8-86a9-c0a463b0b236',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 703228,
#    'NewDeaths': 0,
#    'TotalDeaths': 5708,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '8d3158d9-1553-4e95-b2f8-c0add4d4ee2b',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 640,
#    'TotalConfirmed': 1029701,
#    'NewDeaths': 2,
#    'TotalDeaths': 8596,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '87d2b08c-104d-4755-9fed-09f58fb38f42',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 87,
#    'TotalConfirmed': 46750,
#    'NewDeaths': 1,
#    'TotalDeaths': 670,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '0b09f12a-8156-415d-82b5-4147fcd976c0',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 806256,
#    'NewDeaths': 0,
#    'TotalDeaths': 19820,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9cf08cfc-0992-4a6c-8dd8-e3af7f321233',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4481290,
#    'NewDeaths': 0,
#    'TotalDeaths': 218863,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e8e28984-f2f6-4613-8a5b-07c51b73dc49',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4073216,
#    'NewDeaths': 4,
#    'TotalDeaths': 65779,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '94fc32d3-69d6-445f-bb47-a387e5aa8923',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 989,
#    'TotalConfirmed': 6379391,
#    'NewDeaths': 12,
#    'TotalDeaths': 118727,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'b9c7aadc-3176-48b8-9331-ff5250772d47',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 642,
#    'TotalConfirmed': 5563907,
#    'NewDeaths': 20,
#    'TotalDeaths': 26022,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'bd7c87ca-6da6-43fd-9719-0c235f58ac67',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 60,
#    'TotalConfirmed': 492482,
#    'NewDeaths': 0,
#    'TotalDeaths': 686,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '0311d329-1116-4c54-a66d-c623eca9cf6b',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 272547,
#    'NewDeaths': 0,
#    'TotalDeaths': 3203,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '1537309a-a93d-49b9-b863-726671c836c1',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3325006,
#    'NewDeaths': 0,
#    'TotalDeaths': 67576,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '1d7d5ba4-94ad-420b-acbf-034506b06686',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 5741,
#    'TotalConfirmed': 21640952,
#    'NewDeaths': 44,
#    'TotalDeaths': 387113,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9550f422-c2c5-4a8b-aa91-75d9f14652d9',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 133090,
#    'NewDeaths': 0,
#    'TotalDeaths': 1468,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'd1b0768e-5da7-465d-8460-121914125aac',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6592,
#    'NewDeaths': 0,
#    'TotalDeaths': 46,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '2d9bac37-09ad-405a-bea4-9e478739cd97',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29803,
#    'NewDeaths': 0,
#    'TotalDeaths': 409,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '32306eba-462a-40c3-b06a-36ae5de9a7ef',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 9585,
#    'NewDeaths': 0,
#    'TotalDeaths': 123,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '9ba30abd-1862-4457-9a18-2aaa8dd7c580',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16087,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'e427293f-4684-481d-b930-ad05be50aa01',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23427,
#    'NewDeaths': 0,
#    'TotalDeaths': 122,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '8e867657-b62a-4f31-a346-341b724d3755',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 6280,
#    'NewDeaths': 0,
#    'TotalDeaths': 77,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '16b58810-6c87-49e4-a4bf-86183dc5e96c',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 46,
#    'TotalConfirmed': 827962,
#    'NewDeaths': 3,
#    'TotalDeaths': 9574,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'cdbe19fd-89b9-459d-ad12-6b702ebcd17b',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 88902,
#    'NewDeaths': 0,
#    'TotalDeaths': 1971,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'cb78ce23-42e8-409b-861c-725929e3ad01',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 907,
#    'TotalConfirmed': 2471198,
#    'NewDeaths': 1,
#    'TotalDeaths': 17701,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '93c90465-718b-4046-bcdf-3b851f15664a',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 310,
#    'TotalConfirmed': 50665,
#    'NewDeaths': 0,
#    'TotalDeaths': 172,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7b95e9b1-92d5-47a6-a0b9-3a6fd93f2a86',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7760,
#    'NewDeaths': 0,
#    'TotalDeaths': 126,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '4eeba78f-33b2-4d1d-8525-dca17133d886',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 652,
#    'TotalConfirmed': 2217110,
#    'NewDeaths': 0,
#    'TotalDeaths': 1722,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '5d51e4ae-989c-4536-8522-e737f08f9c48',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 159,
#    'TotalConfirmed': 2660689,
#    'NewDeaths': 2,
#    'TotalDeaths': 20942,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'd8fd6731-538b-4502-ad71-364e703c8e7b',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 359,
#    'TotalConfirmed': 1321579,
#    'NewDeaths': 0,
#    'TotalDeaths': 7056,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'cf8c9236-b7cd-4aaa-bc85-a1d8280670ef',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24575,
#    'NewDeaths': 0,
#    'TotalDeaths': 153,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'be0251b4-a2a5-403e-988c-8960ffba999d',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27318,
#    'NewDeaths': 0,
#    'TotalDeaths': 1361,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '849a1256-7923-494b-9319-3e4c5a642815',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 246,
#    'TotalConfirmed': 4055966,
#    'NewDeaths': 0,
#    'TotalDeaths': 102595,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '23c8926b-87e9-4829-8eea-30ad82f16b3d',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18368,
#    'NewDeaths': 0,
#    'TotalDeaths': 138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '30a1c719-c3a3-427c-9308-460fb049b3c5',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13731478,
#    'NewDeaths': 0,
#    'TotalDeaths': 118434,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '686dee68-6cfa-452d-93ee-b999010da53f',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 671989,
#    'NewDeaths': 0,
#    'TotalDeaths': 16828,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '5942b4dd-db64-45ac-9ad4-f6255b29ffa9',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63742,
#    'NewDeaths': 0,
#    'TotalDeaths': 5001,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7a97d6cd-9110-4cb4-aaab-eaeabfebf075',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 82020,
#    'NewDeaths': 0,
#    'TotalDeaths': 1398,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'b548c839-439c-4a81-b126-d55e44df891d',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 74133,
#    'NewDeaths': 0,
#    'TotalDeaths': 1422,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '1b12bacf-922f-45cf-9beb-c6342c80c742',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2693458,
#    'NewDeaths': 0,
#    'TotalDeaths': 23279,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '6eabace5-378f-47e2-b67e-e228fcf9830c',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 865,
#    'TotalConfirmed': 4407915,
#    'NewDeaths': 0,
#    'TotalDeaths': 14244,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '692dc2e8-e6d0-4739-8c58-70a5bd3b0231',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 57453,
#    'NewDeaths': 0,
#    'TotalDeaths': 3164,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '28d9e749-fd7a-4d31-89d2-de1ca4bd6292',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 32272,
#    'TotalConfirmed': 9537823,
#    'NewDeaths': 32,
#    'TotalDeaths': 16308,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f7c1bb66-1231-4f50-bc56-2db644c90d8c',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17786,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '52ad98d6-431b-40a8-9dbd-537e96c7e7e1',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 64,
#    'TotalConfirmed': 42664,
#    'NewDeaths': 0,
#    'TotalDeaths': 846,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'fb732cae-15ba-49b1-bb8f-894c439f5165',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4726984,
#    'NewDeaths': 0,
#    'TotalDeaths': 33865,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '7361f0a5-da64-4287-9ad8-d6f66f74e302',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23415,
#    'NewDeaths': 0,
#    'TotalDeaths': 138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '4142a951-3a19-483e-b3e5-5af15b5a0bc3',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39354,
#    'NewDeaths': 0,
#    'TotalDeaths': 290,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f8798e36-4993-4b61-acb4-cc0ba029538e',
#    'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16734,
#    'NewDeaths': 0,
#    'TotalDeaths': 13,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '02b18fae-f771-47f1-acfd-f65e038f26e8',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 323,
#    'TotalConfirmed': 187908,
#    'NewDeaths': 7,
#    'TotalDeaths': 4326,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'df0713d6-3b6f-4c74-b4b7-ed85df1bbe94',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 78,
#    'TotalConfirmed': 1150356,
#    'NewDeaths': 6,
#    'TotalDeaths': 29308,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '6871de8a-c4c3-44ae-9134-fd5c36b700cd',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17042722,
#    'NewDeaths': 0,
#    'TotalDeaths': 101492,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'ce0a0688-180f-4e43-83d0-c9d291647547',
#    'Country': 'Tuvalu',
#    'CountryCode': 'TV',
#    'Slug': 'tuvalu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2805,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '040f1722-0c2a-4d3a-91ce-313c0204ffd1',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 72,
#    'TotalConfirmed': 170400,
#    'NewDeaths': 0,
#    'TotalDeaths': 3630,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '6ae61924-ad03-48e4-a328-5aa93f4bb45a',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 51,
#    'TotalConfirmed': 5679371,
#    'NewDeaths': 1,
#    'TotalDeaths': 118974,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '4711f783-1a16-423a-8a36-a86b17b80ebb',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 64,
#    'TotalConfirmed': 1049409,
#    'NewDeaths': 0,
#    'TotalDeaths': 2348,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '245f4a6e-96a6-4591-8edb-dd6ac76f8fbe',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24507298,
#    'NewDeaths': 0,
#    'TotalDeaths': 218028,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'f1f0e127-3b86-4e15-9b16-239f45355d4a',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 35040,
#    'TotalConfirmed': 102345676,
#    'NewDeaths': 627,
#    'TotalDeaths': 1108482,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '3f48e6e5-86b1-4b26-9f32-e415c5888a0a',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1032710,
#    'NewDeaths': 0,
#    'TotalDeaths': 7609,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'db7aa5b7-dae7-4b8b-8bbd-7475c6ace590',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 250567,
#    'NewDeaths': 0,
#    'TotalDeaths': 1637,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'c73e59d4-4038-4684-8ea8-cd100a6a00ca',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12014,
#    'NewDeaths': 0,
#    'TotalDeaths': 14,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '58e45c45-5ef3-4f48-909a-b48e7444ce0d',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 45,
#    'TotalConfirmed': 551587,
#    'NewDeaths': 0,
#    'TotalDeaths': 5845,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '2272e047-0c9c-4361-939b-edb38d462ee6',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 36,
#    'TotalConfirmed': 11526497,
#    'NewDeaths': 0,
#    'TotalDeaths': 43186,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': 'bf4372ca-1d2d-402e-a2d5-7f10513f7d61',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11945,
#    'NewDeaths': 0,
#    'TotalDeaths': 2159,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '371987de-724c-4379-bda5-00bb635247e8',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 181,
#    'TotalConfirmed': 340763,
#    'NewDeaths': 1,
#    'TotalDeaths': 4047,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}},
#   {'ID': '1265b0ad-b2b0-4727-850c-48be94b0b777',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 261606,
#    'NewDeaths': 0,
#    'TotalDeaths': 5652,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-02T12:39:30.535Z',
#    'Premium': {}}],
#  'Date': '2023-02-02T12:39:30.535Z'}

# %%
json.keys()
# Out:
# dict_keys(['ID', 'Message', 'Global', 'Countries', 'Date'])

# %%
json['Countries']
# Out:
# [{'ID': 'd71c39e7-76dd-43d3-90c9-39b7298054f9',
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 43,
#   'TotalConfirmed': 208545,
#   'NewDeaths': 3,
#   'TotalDeaths': 7882,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e69188a8-3c0d-4414-8805-0963d08b81c1',
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 10,
#   'TotalConfirmed': 334167,
#   'NewDeaths': 0,
#   'TotalDeaths': 3596,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '757ae08f-23d0-4c39-bbf2-f5693b60ce1d',
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 271378,
#   'NewDeaths': 0,
#   'TotalDeaths': 6881,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'fab05bf5-d9e5-4e71-8c45-3f90ffcfd12d',
#   'Country': 'Andorra',
#   'CountryCode': 'AD',
#   'Slug': 'andorra',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 47839,
#   'NewDeaths': 0,
#   'TotalDeaths': 165,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e3c286b7-3023-43e1-a1bf-02102dc3af1f',
#   'Country': 'Angola',
#   'CountryCode': 'AO',
#   'Slug': 'angola',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 105184,
#   'NewDeaths': 0,
#   'TotalDeaths': 1931,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '2a859bbd-5fb3-4a3f-9c3f-4dcc857ef273',
#   'Country': 'Antarctica',
#   'CountryCode': 'AQ',
#   'Slug': 'antarctica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '4c6b31b3-9b8d-4f86-8611-c9b06fe5a250',
#   'Country': 'Antigua and Barbuda',
#   'CountryCode': 'AG',
#   'Slug': 'antigua-and-barbuda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9106,
#   'NewDeaths': 0,
#   'TotalDeaths': 146,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f4c54b9f-b940-4e6d-b43b-6c438cfa2466',
#   'Country': 'Argentina',
#   'CountryCode': 'AR',
#   'Slug': 'argentina',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10037135,
#   'NewDeaths': 0,
#   'TotalDeaths': 130421,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f3490240-982c-44f2-9f8d-acf61fc95d99',
#   'Country': 'Armenia',
#   'CountryCode': 'AM',
#   'Slug': 'armenia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 446008,
#   'NewDeaths': 0,
#   'TotalDeaths': 8717,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '2641ec32-553e-4d42-a5ec-2225d93e4fe6',
#   'Country': 'Australia',
#   'CountryCode': 'AU',
#   'Slug': 'australia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11295446,
#   'NewDeaths': 0,
#   'TotalDeaths': 18615,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'c23d9e9d-f27a-4094-be22-5803f604b14b',
#   'Country': 'Austria',
#   'CountryCode': 'AT',
#   'Slug': 'austria',
#   'NewConfirmed': 3482,
#   'TotalConfirmed': 5780229,
#   'NewDeaths': 27,
#   'TotalDeaths': 21689,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'a3f0df3f-f785-45bf-92ec-88e793b92272',
#   'Country': 'Azerbaijan',
#   'CountryCode': 'AZ',
#   'Slug': 'azerbaijan',
#   'NewConfirmed': 35,
#   'TotalConfirmed': 827944,
#   'NewDeaths': 4,
#   'TotalDeaths': 10085,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '95667a14-c37c-4e7d-a056-8885933ae8a6',
#   'Country': 'Bahamas',
#   'CountryCode': 'BS',
#   'Slug': 'bahamas',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 37491,
#   'NewDeaths': 0,
#   'TotalDeaths': 833,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'ef4f6daf-336d-4e84-876c-cd72611e014e',
#   'Country': 'Bahrain',
#   'CountryCode': 'BH',
#   'Slug': 'bahrain',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 700452,
#   'NewDeaths': 0,
#   'TotalDeaths': 1543,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '5303b137-1d06-4d7d-8897-84a5e6b22754',
#   'Country': 'Bangladesh',
#   'CountryCode': 'BD',
#   'Slug': 'bangladesh',
#   'NewConfirmed': 13,
#   'TotalConfirmed': 2037556,
#   'NewDeaths': 0,
#   'TotalDeaths': 29442,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9514ba09-e2c5-4d10-bd3b-d31adb3984ea',
#   'Country': 'Barbados',
#   'CountryCode': 'BB',
#   'Slug': 'barbados',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 106157,
#   'NewDeaths': 0,
#   'TotalDeaths': 571,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'ce0ff53b-8245-4615-ae15-a4171c560559',
#   'Country': 'Belarus',
#   'CountryCode': 'BY',
#   'Slug': 'belarus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 994037,
#   'NewDeaths': 0,
#   'TotalDeaths': 7118,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'a7b86d4c-776b-4142-a242-649096eb3d1d',
#   'Country': 'Belgium',
#   'CountryCode': 'BE',
#   'Slug': 'belgium',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4691499,
#   'NewDeaths': 0,
#   'TotalDeaths': 33557,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '087a7794-fa62-4bb3-a7b0-a85e0161ebd0',
#   'Country': 'Belize',
#   'CountryCode': 'BZ',
#   'Slug': 'belize',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 70660,
#   'NewDeaths': 0,
#   'TotalDeaths': 688,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'b279b956-140c-4a7a-a786-bc02b32a3a31',
#   'Country': 'Benin',
#   'CountryCode': 'BJ',
#   'Slug': 'benin',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27989,
#   'NewDeaths': 0,
#   'TotalDeaths': 163,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'd73c1c87-7950-417b-8d89-4cf7c36277c6',
#   'Country': 'Bhutan',
#   'CountryCode': 'BT',
#   'Slug': 'bhutan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 62605,
#   'NewDeaths': 0,
#   'TotalDeaths': 21,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '28f95dc3-b29b-4fe2-ab82-59d8090a29d4',
#   'Country': 'Bolivia',
#   'CountryCode': 'BO',
#   'Slug': 'bolivia',
#   'NewConfirmed': 301,
#   'TotalConfirmed': 1187986,
#   'NewDeaths': 1,
#   'TotalDeaths': 22346,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '25729c10-1d63-4f64-a76f-59d8a8bde1f2',
#   'Country': 'Bosnia and Herzegovina',
#   'CountryCode': 'BA',
#   'Slug': 'bosnia-and-herzegovina',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 401384,
#   'NewDeaths': 1,
#   'TotalDeaths': 16255,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '4aab15ef-4a09-44c4-800e-2a184d0cbde5',
#   'Country': 'Botswana',
#   'CountryCode': 'BW',
#   'Slug': 'botswana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 329227,
#   'NewDeaths': 0,
#   'TotalDeaths': 2800,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '63961099-2f60-4716-816a-9199a0e65ba3',
#   'Country': 'Brazil',
#   'CountryCode': 'BR',
#   'Slug': 'brazil',
#   'NewConfirmed': 16766,
#   'TotalConfirmed': 36824580,
#   'NewDeaths': 182,
#   'TotalDeaths': 697074,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7348350a-b9c4-4c2b-8b81-8e51ef4dea66',
#   'Country': 'Brunei Darussalam',
#   'CountryCode': 'BN',
#   'Slug': 'brunei',
#   'NewConfirmed': 847,
#   'TotalConfirmed': 276067,
#   'NewDeaths': 0,
#   'TotalDeaths': 225,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '222033bb-6fcb-40be-befd-e37fce8393cc',
#   'Country': 'Bulgaria',
#   'CountryCode': 'BG',
#   'Slug': 'bulgaria',
#   'NewConfirmed': 60,
#   'TotalConfirmed': 1295426,
#   'NewDeaths': 0,
#   'TotalDeaths': 38179,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7753e8de-2ca1-4f01-bc78-19675edd02f6',
#   'Country': 'Burkina Faso',
#   'CountryCode': 'BF',
#   'Slug': 'burkina-faso',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 22025,
#   'NewDeaths': 0,
#   'TotalDeaths': 396,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '2bb6dd69-331e-42bf-9a53-4c3705e5c662',
#   'Country': 'Burundi',
#   'CountryCode': 'BI',
#   'Slug': 'burundi',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 53355,
#   'NewDeaths': 0,
#   'TotalDeaths': 38,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '1e3b9da8-a80b-4d51-a5c0-0247182117cc',
#   'Country': 'Cambodia',
#   'CountryCode': 'KH',
#   'Slug': 'cambodia',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 138693,
#   'NewDeaths': 0,
#   'TotalDeaths': 3056,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e69b5674-a3bf-4190-af8e-e65cdf5111dc',
#   'Country': 'Cameroon',
#   'CountryCode': 'CM',
#   'Slug': 'cameroon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 123993,
#   'NewDeaths': 0,
#   'TotalDeaths': 1965,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '79e07de0-11d2-4517-b488-96f39ff3a25f',
#   'Country': 'Canada',
#   'CountryCode': 'CA',
#   'Slug': 'canada',
#   'NewConfirmed': 924,
#   'TotalConfirmed': 3937494,
#   'NewDeaths': 20,
#   'TotalDeaths': 45095,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7e47d484-f2a6-426c-b752-8998843da58f',
#   'Country': 'Cape Verde',
#   'CountryCode': 'CV',
#   'Slug': 'cape-verde',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 63229,
#   'NewDeaths': 0,
#   'TotalDeaths': 413,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9fa92d53-60ad-4122-89eb-fdd09ef7638c',
#   'Country': 'Central African Republic',
#   'CountryCode': 'CF',
#   'Slug': 'central-african-republic',
#   'NewConfirmed': 7,
#   'TotalConfirmed': 15368,
#   'NewDeaths': 0,
#   'TotalDeaths': 113,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '572c3cae-d4e1-4440-b1fb-c255cd49cc77',
#   'Country': 'Chad',
#   'CountryCode': 'TD',
#   'Slug': 'chad',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7652,
#   'NewDeaths': 0,
#   'TotalDeaths': 194,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '3c27f8f8-3d3a-486a-b8ef-9f622c88fb21',
#   'Country': 'Chile',
#   'CountryCode': 'CL',
#   'Slug': 'chile',
#   'NewConfirmed': 1029,
#   'TotalConfirmed': 5118981,
#   'NewDeaths': 6,
#   'TotalDeaths': 63812,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'b29cb984-f5ea-48a4-ab52-6c8c2d632433',
#   'Country': 'China',
#   'CountryCode': 'CN',
#   'Slug': 'china',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 3381681,
#   'NewDeaths': 0,
#   'TotalDeaths': 18726,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '8a717f7f-9558-487f-9928-219a1a9a6524',
#   'Country': 'Colombia',
#   'CountryCode': 'CO',
#   'Slug': 'colombia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6352923,
#   'NewDeaths': 0,
#   'TotalDeaths': 142186,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '1d3c6725-3207-4cfc-8400-ef01666302a9',
#   'Country': 'Comoros',
#   'CountryCode': 'KM',
#   'Slug': 'comoros',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8992,
#   'NewDeaths': 0,
#   'TotalDeaths': 161,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'adc1fd4b-4139-4b7b-8212-7538f66eab33',
#   'Country': 'Congo (Brazzaville)',
#   'CountryCode': 'CG',
#   'Slug': 'congo-brazzaville',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 25375,
#   'NewDeaths': 0,
#   'TotalDeaths': 388,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '3185e238-e128-4111-a979-0b796ffb2541',
#   'Country': 'Congo (Kinshasa)',
#   'CountryCode': 'CD',
#   'Slug': 'congo-kinshasa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 95514,
#   'NewDeaths': 0,
#   'TotalDeaths': 1463,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'cd041f65-4021-406f-9cee-51c5106bc773',
#   'Country': 'Costa Rica',
#   'CountryCode': 'CR',
#   'Slug': 'costa-rica',
#   'NewConfirmed': 3805,
#   'TotalConfirmed': 1186176,
#   'NewDeaths': 16,
#   'TotalDeaths': 9158,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'de9be235-706b-4d07-a301-edca3a83c50d',
#   'Country': 'Croatia',
#   'CountryCode': 'HR',
#   'Slug': 'croatia',
#   'NewConfirmed': 56,
#   'TotalConfirmed': 1267580,
#   'NewDeaths': 6,
#   'TotalDeaths': 17877,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9cb8ee00-ca5e-4f32-bb52-5a31c3a41bbe',
#   'Country': 'Cuba',
#   'CountryCode': 'CU',
#   'Slug': 'cuba',
#   'NewConfirmed': 9,
#   'TotalConfirmed': 1112438,
#   'NewDeaths': 0,
#   'TotalDeaths': 8530,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'bd710b88-0fb5-4060-b950-f3a70d582959',
#   'Country': 'Cyprus',
#   'CountryCode': 'CY',
#   'Slug': 'cyprus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 642663,
#   'NewDeaths': 0,
#   'TotalDeaths': 1287,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '53f2d09a-7f9c-4e86-93bc-98d22b42eb6c',
#   'Country': 'Czech Republic',
#   'CountryCode': 'CZ',
#   'Slug': 'czech-republic',
#   'NewConfirmed': 663,
#   'TotalConfirmed': 4589483,
#   'NewDeaths': 3,
#   'TotalDeaths': 42307,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'cb9dd293-5f51-4ce3-9ec2-2599bc1c2dc6',
#   'Country': "Côte d'Ivoire",
#   'CountryCode': 'CI',
#   'Slug': 'cote-divoire',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 87982,
#   'NewDeaths': 0,
#   'TotalDeaths': 833,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'dee105b8-5a16-4633-baf4-2c9f6d70f86e',
#   'Country': 'Denmark',
#   'CountryCode': 'DK',
#   'Slug': 'denmark',
#   'NewConfirmed': 204,
#   'TotalConfirmed': 3446409,
#   'NewDeaths': 7,
#   'TotalDeaths': 8194,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'd4eed420-1297-4110-8ab8-edfc54247314',
#   'Country': 'Djibouti',
#   'CountryCode': 'DJ',
#   'Slug': 'djibouti',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15690,
#   'NewDeaths': 0,
#   'TotalDeaths': 189,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e0baf955-3f3e-4a49-b83d-f448efc8c647',
#   'Country': 'Dominica',
#   'CountryCode': 'DM',
#   'Slug': 'dominica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15760,
#   'NewDeaths': 0,
#   'TotalDeaths': 74,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7e6f49d0-9b12-450c-9c85-0115940948ee',
#   'Country': 'Dominican Republic',
#   'CountryCode': 'DO',
#   'Slug': 'dominican-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 660095,
#   'NewDeaths': 0,
#   'TotalDeaths': 4384,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '47499672-64d6-4ae0-9d87-6e1b5413383a',
#   'Country': 'Ecuador',
#   'CountryCode': 'EC',
#   'Slug': 'ecuador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1051239,
#   'NewDeaths': 0,
#   'TotalDeaths': 35942,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'bd2cea1c-f4f7-49b4-925b-82ae7936e33e',
#   'Country': 'Egypt',
#   'CountryCode': 'EG',
#   'Slug': 'egypt',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 515645,
#   'NewDeaths': 0,
#   'TotalDeaths': 24805,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e382022e-07c2-47a2-bf22-a745bfbe16f3',
#   'Country': 'El Salvador',
#   'CountryCode': 'SV',
#   'Slug': 'el-salvador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 201785,
#   'NewDeaths': 0,
#   'TotalDeaths': 4230,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '103e80ca-e1e8-4e56-b213-6c0a2b664128',
#   'Country': 'Equatorial Guinea',
#   'CountryCode': 'GQ',
#   'Slug': 'equatorial-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17190,
#   'NewDeaths': 0,
#   'TotalDeaths': 183,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'fbe84416-d0a6-4214-8c25-be2578ec1059',
#   'Country': 'Eritrea',
#   'CountryCode': 'ER',
#   'Slug': 'eritrea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10189,
#   'NewDeaths': 0,
#   'TotalDeaths': 103,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9881eb48-a82a-469e-b4e4-acebc7188fd9',
#   'Country': 'Estonia',
#   'CountryCode': 'EE',
#   'Slug': 'estonia',
#   'NewConfirmed': 372,
#   'TotalConfirmed': 613903,
#   'NewDeaths': 8,
#   'TotalDeaths': 2912,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '771dc6c8-f7cb-4228-9f90-27fbfb233dd2',
#   'Country': 'Ethiopia',
#   'CountryCode': 'ET',
#   'Slug': 'ethiopia',
#   'NewConfirmed': 38,
#   'TotalConfirmed': 499531,
#   'NewDeaths': 0,
#   'TotalDeaths': 7572,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'd42ccf52-2a6b-40ef-aebc-f13621deddec',
#   'Country': 'Fiji',
#   'CountryCode': 'FJ',
#   'Slug': 'fiji',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 68820,
#   'NewDeaths': 0,
#   'TotalDeaths': 883,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'c94fa5f1-ca35-4353-89b6-6591c338550d',
#   'Country': 'Finland',
#   'CountryCode': 'FI',
#   'Slug': 'finland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1458619,
#   'NewDeaths': 0,
#   'TotalDeaths': 8639,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '68a49909-0a9a-4f73-87a5-c0db0a9b4a06',
#   'Country': 'France',
#   'CountryCode': 'FR',
#   'Slug': 'france',
#   'NewConfirmed': 6860,
#   'TotalConfirmed': 39729161,
#   'NewDeaths': 57,
#   'TotalDeaths': 165274,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '48b4f426-51e3-460b-88fc-6fb251915668',
#   'Country': 'Gabon',
#   'CountryCode': 'GA',
#   'Slug': 'gabon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 48981,
#   'NewDeaths': 0,
#   'TotalDeaths': 306,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '08a38938-9a8e-48f9-9ca8-63bd3c9cba8f',
#   'Country': 'Gambia',
#   'CountryCode': 'GM',
#   'Slug': 'gambia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 12586,
#   'NewDeaths': 0,
#   'TotalDeaths': 372,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e80faf66-8519-4baf-9952-976040989f15',
#   'Country': 'Georgia',
#   'CountryCode': 'GE',
#   'Slug': 'georgia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1814180,
#   'NewDeaths': 0,
#   'TotalDeaths': 16926,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9d9ebed4-40c7-4bb8-8f8a-b2202a1db96d',
#   'Country': 'Germany',
#   'CountryCode': 'DE',
#   'Slug': 'germany',
#   'NewConfirmed': 21060,
#   'TotalConfirmed': 37779833,
#   'NewDeaths': 148,
#   'TotalDeaths': 165711,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '62a3a697-0b97-4e27-925b-50532add47c1',
#   'Country': 'Ghana',
#   'CountryCode': 'GH',
#   'Slug': 'ghana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 171112,
#   'NewDeaths': 0,
#   'TotalDeaths': 1462,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e4121fc9-bb8e-408a-a012-3e5b5e053fa3',
#   'Country': 'Greece',
#   'CountryCode': 'GR',
#   'Slug': 'greece',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5548487,
#   'NewDeaths': 0,
#   'TotalDeaths': 34779,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '6f088953-dff8-4ddd-a08c-22448a3f3d10',
#   'Country': 'Grenada',
#   'CountryCode': 'GD',
#   'Slug': 'grenada',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 19680,
#   'NewDeaths': 0,
#   'TotalDeaths': 238,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '967b39f7-af5d-49d2-8c24-d347f960061c',
#   'Country': 'Guatemala',
#   'CountryCode': 'GT',
#   'Slug': 'guatemala',
#   'NewConfirmed': 811,
#   'TotalConfirmed': 1227853,
#   'NewDeaths': 5,
#   'TotalDeaths': 20106,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f567b26e-c69b-45d5-bd0a-f1dda4402a35',
#   'Country': 'Guinea',
#   'CountryCode': 'GN',
#   'Slug': 'guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 38240,
#   'NewDeaths': 0,
#   'TotalDeaths': 467,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '3440e9ff-7283-4392-96e0-6ea5ee97abef',
#   'Country': 'Guinea-Bissau',
#   'CountryCode': 'GW',
#   'Slug': 'guinea-bissau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8947,
#   'NewDeaths': 0,
#   'TotalDeaths': 176,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'ca385344-86fb-4c8f-818c-af7e46d4cbf9',
#   'Country': 'Guyana',
#   'CountryCode': 'GY',
#   'Slug': 'guyana',
#   'NewConfirmed': 28,
#   'TotalConfirmed': 72950,
#   'NewDeaths': 0,
#   'TotalDeaths': 1294,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '24ea5aed-4f67-41a3-ae5f-52cdf60e1cdc',
#   'Country': 'Haiti',
#   'CountryCode': 'HT',
#   'Slug': 'haiti',
#   'NewConfirmed': 68,
#   'TotalConfirmed': 34076,
#   'NewDeaths': 0,
#   'TotalDeaths': 860,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'ff3e17bd-d730-4249-9850-c5f1ea04bbcb',
#   'Country': 'Holy See (Vatican City State)',
#   'CountryCode': 'VA',
#   'Slug': 'holy-see-vatican-city-state',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 29,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'b17cde61-6b0e-4ea5-b39f-40f0ca52b315',
#   'Country': 'Honduras',
#   'CountryCode': 'HN',
#   'Slug': 'honduras',
#   'NewConfirmed': 420,
#   'TotalConfirmed': 470757,
#   'NewDeaths': 2,
#   'TotalDeaths': 11104,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '661e1ba6-d6dd-4467-9f6c-69d074ef08d8',
#   'Country': 'Hungary',
#   'CountryCode': 'HU',
#   'Slug': 'hungary',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2191827,
#   'NewDeaths': 0,
#   'TotalDeaths': 48658,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'cad9637f-b737-4ed4-a96a-6eed70a0ef7c',
#   'Country': 'Iceland',
#   'CountryCode': 'IS',
#   'Slug': 'iceland',
#   'NewConfirmed': 83,
#   'TotalConfirmed': 208688,
#   'NewDeaths': 0,
#   'TotalDeaths': 199,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '36d8d417-75b6-4d38-848b-9a51c12fc518',
#   'Country': 'India',
#   'CountryCode': 'IN',
#   'Slug': 'india',
#   'NewConfirmed': 111,
#   'TotalConfirmed': 44684120,
#   'NewDeaths': 0,
#   'TotalDeaths': 530740,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'c708a8d7-cd81-46d4-a724-364b8fb11493',
#   'Country': 'Indonesia',
#   'CountryCode': 'ID',
#   'Slug': 'indonesia',
#   'NewConfirmed': 260,
#   'TotalConfirmed': 6730016,
#   'NewDeaths': 4,
#   'TotalDeaths': 160814,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'c1102996-3364-4bc8-b6d8-86ea710dd8c5',
#   'Country': 'Iran, Islamic Republic of',
#   'CountryCode': 'IR',
#   'Slug': 'iran',
#   'NewConfirmed': 98,
#   'TotalConfirmed': 7564350,
#   'NewDeaths': 2,
#   'TotalDeaths': 144749,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '01034fbf-a69f-4980-8b16-4b6ab74fb5fa',
#   'Country': 'Iraq',
#   'CountryCode': 'IQ',
#   'Slug': 'iraq',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2465545,
#   'NewDeaths': 0,
#   'TotalDeaths': 25375,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'b415bb39-ee37-464b-a7d2-31019039c841',
#   'Country': 'Ireland',
#   'CountryCode': 'IE',
#   'Slug': 'ireland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1700253,
#   'NewDeaths': 0,
#   'TotalDeaths': 8462,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9c584508-412d-4e69-8840-33656eadabd3',
#   'Country': 'Israel',
#   'CountryCode': 'IL',
#   'Slug': 'israel',
#   'NewConfirmed': 872,
#   'TotalConfirmed': 4786180,
#   'NewDeaths': 16,
#   'TotalDeaths': 12193,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '5c6f19f0-8ae2-413f-bcdd-c618a3e1acd3',
#   'Country': 'Italy',
#   'CountryCode': 'IT',
#   'Slug': 'italy',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 25453789,
#   'NewDeaths': 0,
#   'TotalDeaths': 186833,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7a5f8eb3-ed13-47a6-b06f-cf00266071fb',
#   'Country': 'Jamaica',
#   'CountryCode': 'JM',
#   'Slug': 'jamaica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 153407,
#   'NewDeaths': 0,
#   'TotalDeaths': 3480,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f5f9fcbe-384a-4044-acc0-2eaffcff0585',
#   'Country': 'Japan',
#   'CountryCode': 'JP',
#   'Slug': 'japan',
#   'NewConfirmed': 47118,
#   'TotalConfirmed': 32555047,
#   'NewDeaths': 246,
#   'TotalDeaths': 68099,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '15b16dd5-1175-42a3-8200-1a7e0c94ef88',
#   'Country': 'Jordan',
#   'CountryCode': 'JO',
#   'Slug': 'jordan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1746997,
#   'NewDeaths': 0,
#   'TotalDeaths': 14122,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'bd68d8c5-3611-4a01-8a65-9aee5316096e',
#   'Country': 'Kazakhstan',
#   'CountryCode': 'KZ',
#   'Slug': 'kazakhstan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1496549,
#   'NewDeaths': 0,
#   'TotalDeaths': 19065,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'd53f2c97-1d0d-4ab6-a600-8484d3712dcf',
#   'Country': 'Kenya',
#   'CountryCode': 'KE',
#   'Slug': 'kenya',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 342810,
#   'NewDeaths': 0,
#   'TotalDeaths': 5688,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '541a1f43-7416-4805-b2a9-20f04882007f',
#   'Country': 'Kiribati',
#   'CountryCode': 'KI',
#   'Slug': 'kiribati',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5008,
#   'NewDeaths': 0,
#   'TotalDeaths': 18,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '48c42e57-1b00-4c82-8121-5b44c93d974e',
#   'Country': 'Korea (North)',
#   'CountryCode': 'KP',
#   'Slug': 'korea-north',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1,
#   'NewDeaths': 0,
#   'TotalDeaths': 6,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '0ce20f0d-5c05-4d8a-a054-924438264c15',
#   'Country': 'Korea (South)',
#   'CountryCode': 'KR',
#   'Slug': 'korea-south',
#   'NewConfirmed': 20420,
#   'TotalConfirmed': 30197066,
#   'NewDeaths': 42,
#   'TotalDeaths': 33486,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '26d71cf3-f6ef-4143-8bb4-61d3dd962d87',
#   'Country': 'Kuwait',
#   'CountryCode': 'KW',
#   'Slug': 'kuwait',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 662858,
#   'NewDeaths': 0,
#   'TotalDeaths': 2570,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f9a79894-e754-4c75-9e8f-b2a9b3aacdca',
#   'Country': 'Kyrgyzstan',
#   'CountryCode': 'KG',
#   'Slug': 'kyrgyzstan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 206592,
#   'NewDeaths': 0,
#   'TotalDeaths': 2991,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '32dbb548-674e-4ba8-a6ba-6cccf3e64d3f',
#   'Country': 'Lao PDR',
#   'CountryCode': 'LA',
#   'Slug': 'lao-pdr',
#   'NewConfirmed': 4,
#   'TotalConfirmed': 217973,
#   'NewDeaths': 0,
#   'TotalDeaths': 758,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '8d37853f-c9c9-450d-932a-2852d14a35e3',
#   'Country': 'Latvia',
#   'CountryCode': 'LV',
#   'Slug': 'latvia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 975282,
#   'NewDeaths': 0,
#   'TotalDeaths': 6214,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '8b33b322-3d12-4db6-96ec-4f4cdb4b32dd',
#   'Country': 'Lebanon',
#   'CountryCode': 'LB',
#   'Slug': 'lebanon',
#   'NewConfirmed': 135,
#   'TotalConfirmed': 1228639,
#   'NewDeaths': 2,
#   'TotalDeaths': 10790,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'c83e97f5-0358-4957-902c-9b40d2a7de53',
#   'Country': 'Lesotho',
#   'CountryCode': 'LS',
#   'Slug': 'lesotho',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 34790,
#   'NewDeaths': 0,
#   'TotalDeaths': 723,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '0051513b-8162-457b-8291-710e736376e8',
#   'Country': 'Liberia',
#   'CountryCode': 'LR',
#   'Slug': 'liberia',
#   'NewConfirmed': 9,
#   'TotalConfirmed': 8062,
#   'NewDeaths': 0,
#   'TotalDeaths': 294,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'fa5ae427-43d1-4da9-8a4a-470417127c90',
#   'Country': 'Libya',
#   'CountryCode': 'LY',
#   'Slug': 'libya',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 507162,
#   'NewDeaths': 0,
#   'TotalDeaths': 6437,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '04cdd42f-f619-4b7f-af43-a04d2b61c977',
#   'Country': 'Liechtenstein',
#   'CountryCode': 'LI',
#   'Slug': 'liechtenstein',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 21349,
#   'NewDeaths': 0,
#   'TotalDeaths': 89,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'fbd7e4b4-10e1-46de-84b1-ac24fbdbcec3',
#   'Country': 'Lithuania',
#   'CountryCode': 'LT',
#   'Slug': 'lithuania',
#   'NewConfirmed': 535,
#   'TotalConfirmed': 1296493,
#   'NewDeaths': 1,
#   'TotalDeaths': 9541,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e85b5c34-7f79-4792-a4f6-9147d919ee35',
#   'Country': 'Luxembourg',
#   'CountryCode': 'LU',
#   'Slug': 'luxembourg',
#   'NewConfirmed': 92,
#   'TotalConfirmed': 314731,
#   'NewDeaths': 3,
#   'TotalDeaths': 1210,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '671ac061-6ac4-4856-8f91-ae3b33a6ae6e',
#   'Country': 'Macedonia, Republic of',
#   'CountryCode': 'MK',
#   'Slug': 'macedonia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 346428,
#   'NewDeaths': 0,
#   'TotalDeaths': 9638,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'c58d615d-e37e-4e73-ad88-8df787da8a46',
#   'Country': 'Madagascar',
#   'CountryCode': 'MG',
#   'Slug': 'madagascar',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 67827,
#   'NewDeaths': 0,
#   'TotalDeaths': 1419,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'be5caaaf-c3fa-41d4-9fcd-c55a09cdedc3',
#   'Country': 'Malawi',
#   'CountryCode': 'MW',
#   'Slug': 'malawi',
#   'NewConfirmed': 54,
#   'TotalConfirmed': 88559,
#   'NewDeaths': 0,
#   'TotalDeaths': 2686,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7f0d7ce4-6029-4232-bed8-ee334967cdcd',
#   'Country': 'Malaysia',
#   'CountryCode': 'MY',
#   'Slug': 'malaysia',
#   'NewConfirmed': 251,
#   'TotalConfirmed': 5036593,
#   'NewDeaths': 0,
#   'TotalDeaths': 36942,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '0c8f4d0a-fbee-404e-a0fc-bb24c94a3f6a',
#   'Country': 'Maldives',
#   'CountryCode': 'MV',
#   'Slug': 'maldives',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 185715,
#   'NewDeaths': 0,
#   'TotalDeaths': 311,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'cce30a5e-282d-4336-9a84-d092bf44c6ae',
#   'Country': 'Mali',
#   'CountryCode': 'ML',
#   'Slug': 'mali',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 32783,
#   'NewDeaths': 0,
#   'TotalDeaths': 743,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '063a644e-c68e-43d9-88ad-2b73c655bae1',
#   'Country': 'Malta',
#   'CountryCode': 'MT',
#   'Slug': 'malta',
#   'NewConfirmed': 109,
#   'TotalConfirmed': 117062,
#   'NewDeaths': 0,
#   'TotalDeaths': 824,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '689ad444-c6d9-45e5-b616-552d2272bb20',
#   'Country': 'Marshall Islands',
#   'CountryCode': 'MH',
#   'Slug': 'marshall-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15584,
#   'NewDeaths': 0,
#   'TotalDeaths': 17,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '0edccd18-f09d-4793-8db9-799691931106',
#   'Country': 'Mauritania',
#   'CountryCode': 'MR',
#   'Slug': 'mauritania',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 63665,
#   'NewDeaths': 0,
#   'TotalDeaths': 997,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '756ed661-ae8d-4fdd-ae34-72a969a2d3fa',
#   'Country': 'Mauritius',
#   'CountryCode': 'MU',
#   'Slug': 'mauritius',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 294602,
#   'NewDeaths': 0,
#   'TotalDeaths': 1043,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '2c6671ff-731e-4f85-aba9-55c828cb46b6',
#   'Country': 'Mexico',
#   'CountryCode': 'MX',
#   'Slug': 'mexico',
#   'NewConfirmed': 540,
#   'TotalConfirmed': 7368252,
#   'NewDeaths': 8,
#   'TotalDeaths': 332198,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'fa182f1b-28bc-40de-97b8-75210334a634',
#   'Country': 'Micronesia, Federated States of',
#   'CountryCode': 'FM',
#   'Slug': 'micronesia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 22676,
#   'NewDeaths': 0,
#   'TotalDeaths': 58,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '3d571c4b-e976-4a15-83e7-afd36a58db27',
#   'Country': 'Moldova',
#   'CountryCode': 'MD',
#   'Slug': 'moldova',
#   'NewConfirmed': 600,
#   'TotalConfirmed': 598673,
#   'NewDeaths': 3,
#   'TotalDeaths': 11953,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9f140380-e99b-4481-ae59-73d0027fec62',
#   'Country': 'Monaco',
#   'CountryCode': 'MC',
#   'Slug': 'monaco',
#   'NewConfirmed': 7,
#   'TotalConfirmed': 16063,
#   'NewDeaths': 0,
#   'TotalDeaths': 65,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '2a47b350-1837-49ab-863c-4fddd17ab736',
#   'Country': 'Mongolia',
#   'CountryCode': 'MN',
#   'Slug': 'mongolia',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 1007871,
#   'NewDeaths': 0,
#   'TotalDeaths': 2136,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'ded0d051-fd8f-429f-9692-25173bfc7866',
#   'Country': 'Montenegro',
#   'CountryCode': 'ME',
#   'Slug': 'montenegro',
#   'NewConfirmed': 60,
#   'TotalConfirmed': 286355,
#   'NewDeaths': 0,
#   'TotalDeaths': 2797,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '05ae1657-1d87-4fcb-bab2-1fbf254f3898',
#   'Country': 'Morocco',
#   'CountryCode': 'MA',
#   'Slug': 'morocco',
#   'NewConfirmed': 11,
#   'TotalConfirmed': 1272240,
#   'NewDeaths': 0,
#   'TotalDeaths': 16296,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '083687a5-d652-434b-8344-a65f02de80bb',
#   'Country': 'Mozambique',
#   'CountryCode': 'MZ',
#   'Slug': 'mozambique',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 231994,
#   'NewDeaths': 0,
#   'TotalDeaths': 2233,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '67d3e173-b254-4ba1-afcb-945051b4f87f',
#   'Country': 'Myanmar',
#   'CountryCode': 'MM',
#   'Slug': 'myanmar',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 633820,
#   'NewDeaths': 0,
#   'TotalDeaths': 19490,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '0bf4f53f-7178-471d-a4df-e4539ec2d70a',
#   'Country': 'Namibia',
#   'CountryCode': 'NA',
#   'Slug': 'namibia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 170741,
#   'NewDeaths': 0,
#   'TotalDeaths': 4088,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '092340ad-ac66-421e-bfbe-f55ca541258a',
#   'Country': 'Nauru',
#   'CountryCode': 'NR',
#   'Slug': 'nauru',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4621,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '29cc9d4d-1b42-45a4-b865-55d9540528c7',
#   'Country': 'Nepal',
#   'CountryCode': 'NP',
#   'Slug': 'nepal',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 1001100,
#   'NewDeaths': 0,
#   'TotalDeaths': 12020,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '3380ad33-3e08-4083-b924-13350a16491f',
#   'Country': 'Netherlands',
#   'CountryCode': 'NL',
#   'Slug': 'netherlands',
#   'NewConfirmed': 1079,
#   'TotalConfirmed': 8582361,
#   'NewDeaths': 0,
#   'TotalDeaths': 22990,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'ddd9284b-0b33-4faa-9db7-5cb1a5e5ae7f',
#   'Country': 'New Zealand',
#   'CountryCode': 'NZ',
#   'Slug': 'new-zealand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2190095,
#   'NewDeaths': 0,
#   'TotalDeaths': 2479,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'fc0a4657-fe3d-450e-9e95-48a97425c0bd',
#   'Country': 'Nicaragua',
#   'CountryCode': 'NI',
#   'Slug': 'nicaragua',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15569,
#   'NewDeaths': 0,
#   'TotalDeaths': 245,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'abd3cb22-af19-42de-a7ca-9d584b38090b',
#   'Country': 'Niger',
#   'CountryCode': 'NE',
#   'Slug': 'niger',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9508,
#   'NewDeaths': 0,
#   'TotalDeaths': 315,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'd79a967c-bebd-44bf-bcd1-537177020082',
#   'Country': 'Nigeria',
#   'CountryCode': 'NG',
#   'Slug': 'nigeria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 266463,
#   'NewDeaths': 0,
#   'TotalDeaths': 3155,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'a3927215-6561-4954-a32b-c6d379caa210',
#   'Country': 'Norway',
#   'CountryCode': 'NO',
#   'Slug': 'norway',
#   'NewConfirmed': 72,
#   'TotalConfirmed': 1477856,
#   'NewDeaths': 0,
#   'TotalDeaths': 5112,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f92575b1-4caa-444f-9158-9c81e4948006',
#   'Country': 'Oman',
#   'CountryCode': 'OM',
#   'Slug': 'oman',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 399449,
#   'NewDeaths': 0,
#   'TotalDeaths': 4628,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e29ea8d7-417d-4285-b429-f623177e06a4',
#   'Country': 'Pakistan',
#   'CountryCode': 'PK',
#   'Slug': 'pakistan',
#   'NewConfirmed': 19,
#   'TotalConfirmed': 1576312,
#   'NewDeaths': 0,
#   'TotalDeaths': 30640,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '927e75e3-dc7e-4bf9-a392-26a416b7d72d',
#   'Country': 'Palau',
#   'CountryCode': 'PW',
#   'Slug': 'palau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5986,
#   'NewDeaths': 0,
#   'TotalDeaths': 9,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '16520d41-e693-48a8-86a9-c0a463b0b236',
#   'Country': 'Palestinian Territory',
#   'CountryCode': 'PS',
#   'Slug': 'palestine',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 703228,
#   'NewDeaths': 0,
#   'TotalDeaths': 5708,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '8d3158d9-1553-4e95-b2f8-c0add4d4ee2b',
#   'Country': 'Panama',
#   'CountryCode': 'PA',
#   'Slug': 'panama',
#   'NewConfirmed': 640,
#   'TotalConfirmed': 1029701,
#   'NewDeaths': 2,
#   'TotalDeaths': 8596,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '87d2b08c-104d-4755-9fed-09f58fb38f42',
#   'Country': 'Papua New Guinea',
#   'CountryCode': 'PG',
#   'Slug': 'papua-new-guinea',
#   'NewConfirmed': 87,
#   'TotalConfirmed': 46750,
#   'NewDeaths': 1,
#   'TotalDeaths': 670,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '0b09f12a-8156-415d-82b5-4147fcd976c0',
#   'Country': 'Paraguay',
#   'CountryCode': 'PY',
#   'Slug': 'paraguay',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 806256,
#   'NewDeaths': 0,
#   'TotalDeaths': 19820,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9cf08cfc-0992-4a6c-8dd8-e3af7f321233',
#   'Country': 'Peru',
#   'CountryCode': 'PE',
#   'Slug': 'peru',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4481290,
#   'NewDeaths': 0,
#   'TotalDeaths': 218863,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e8e28984-f2f6-4613-8a5b-07c51b73dc49',
#   'Country': 'Philippines',
#   'CountryCode': 'PH',
#   'Slug': 'philippines',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4073216,
#   'NewDeaths': 4,
#   'TotalDeaths': 65779,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '94fc32d3-69d6-445f-bb47-a387e5aa8923',
#   'Country': 'Poland',
#   'CountryCode': 'PL',
#   'Slug': 'poland',
#   'NewConfirmed': 989,
#   'TotalConfirmed': 6379391,
#   'NewDeaths': 12,
#   'TotalDeaths': 118727,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'b9c7aadc-3176-48b8-9331-ff5250772d47',
#   'Country': 'Portugal',
#   'CountryCode': 'PT',
#   'Slug': 'portugal',
#   'NewConfirmed': 642,
#   'TotalConfirmed': 5563907,
#   'NewDeaths': 20,
#   'TotalDeaths': 26022,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'bd7c87ca-6da6-43fd-9719-0c235f58ac67',
#   'Country': 'Qatar',
#   'CountryCode': 'QA',
#   'Slug': 'qatar',
#   'NewConfirmed': 60,
#   'TotalConfirmed': 492482,
#   'NewDeaths': 0,
#   'TotalDeaths': 686,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '0311d329-1116-4c54-a66d-c623eca9cf6b',
#   'Country': 'Republic of Kosovo',
#   'CountryCode': 'XK',
#   'Slug': 'kosovo',
#   'NewConfirmed': 8,
#   'TotalConfirmed': 272547,
#   'NewDeaths': 0,
#   'TotalDeaths': 3203,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '1537309a-a93d-49b9-b863-726671c836c1',
#   'Country': 'Romania',
#   'CountryCode': 'RO',
#   'Slug': 'romania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3325006,
#   'NewDeaths': 0,
#   'TotalDeaths': 67576,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '1d7d5ba4-94ad-420b-acbf-034506b06686',
#   'Country': 'Russian Federation',
#   'CountryCode': 'RU',
#   'Slug': 'russia',
#   'NewConfirmed': 5741,
#   'TotalConfirmed': 21640952,
#   'NewDeaths': 44,
#   'TotalDeaths': 387113,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9550f422-c2c5-4a8b-aa91-75d9f14652d9',
#   'Country': 'Rwanda',
#   'CountryCode': 'RW',
#   'Slug': 'rwanda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 133090,
#   'NewDeaths': 0,
#   'TotalDeaths': 1468,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'd1b0768e-5da7-465d-8460-121914125aac',
#   'Country': 'Saint Kitts and Nevis',
#   'CountryCode': 'KN',
#   'Slug': 'saint-kitts-and-nevis',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6592,
#   'NewDeaths': 0,
#   'TotalDeaths': 46,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '2d9bac37-09ad-405a-bea4-9e478739cd97',
#   'Country': 'Saint Lucia',
#   'CountryCode': 'LC',
#   'Slug': 'saint-lucia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 29803,
#   'NewDeaths': 0,
#   'TotalDeaths': 409,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '32306eba-462a-40c3-b06a-36ae5de9a7ef',
#   'Country': 'Saint Vincent and Grenadines',
#   'CountryCode': 'VC',
#   'Slug': 'saint-vincent-and-the-grenadines',
#   'NewConfirmed': 4,
#   'TotalConfirmed': 9585,
#   'NewDeaths': 0,
#   'TotalDeaths': 123,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '9ba30abd-1862-4457-9a18-2aaa8dd7c580',
#   'Country': 'Samoa',
#   'CountryCode': 'WS',
#   'Slug': 'samoa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 16087,
#   'NewDeaths': 0,
#   'TotalDeaths': 29,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'e427293f-4684-481d-b930-ad05be50aa01',
#   'Country': 'San Marino',
#   'CountryCode': 'SM',
#   'Slug': 'san-marino',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 23427,
#   'NewDeaths': 0,
#   'TotalDeaths': 122,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '8e867657-b62a-4f31-a346-341b724d3755',
#   'Country': 'Sao Tome and Principe',
#   'CountryCode': 'ST',
#   'Slug': 'sao-tome-and-principe',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 6280,
#   'NewDeaths': 0,
#   'TotalDeaths': 77,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '16b58810-6c87-49e4-a4bf-86183dc5e96c',
#   'Country': 'Saudi Arabia',
#   'CountryCode': 'SA',
#   'Slug': 'saudi-arabia',
#   'NewConfirmed': 46,
#   'TotalConfirmed': 827962,
#   'NewDeaths': 3,
#   'TotalDeaths': 9574,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'cdbe19fd-89b9-459d-ad12-6b702ebcd17b',
#   'Country': 'Senegal',
#   'CountryCode': 'SN',
#   'Slug': 'senegal',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 88902,
#   'NewDeaths': 0,
#   'TotalDeaths': 1971,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'cb78ce23-42e8-409b-861c-725929e3ad01',
#   'Country': 'Serbia',
#   'CountryCode': 'RS',
#   'Slug': 'serbia',
#   'NewConfirmed': 907,
#   'TotalConfirmed': 2471198,
#   'NewDeaths': 1,
#   'TotalDeaths': 17701,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '93c90465-718b-4046-bcdf-3b851f15664a',
#   'Country': 'Seychelles',
#   'CountryCode': 'SC',
#   'Slug': 'seychelles',
#   'NewConfirmed': 310,
#   'TotalConfirmed': 50665,
#   'NewDeaths': 0,
#   'TotalDeaths': 172,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7b95e9b1-92d5-47a6-a0b9-3a6fd93f2a86',
#   'Country': 'Sierra Leone',
#   'CountryCode': 'SL',
#   'Slug': 'sierra-leone',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7760,
#   'NewDeaths': 0,
#   'TotalDeaths': 126,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '4eeba78f-33b2-4d1d-8525-dca17133d886',
#   'Country': 'Singapore',
#   'CountryCode': 'SG',
#   'Slug': 'singapore',
#   'NewConfirmed': 652,
#   'TotalConfirmed': 2217110,
#   'NewDeaths': 0,
#   'TotalDeaths': 1722,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '5d51e4ae-989c-4536-8522-e737f08f9c48',
#   'Country': 'Slovakia',
#   'CountryCode': 'SK',
#   'Slug': 'slovakia',
#   'NewConfirmed': 159,
#   'TotalConfirmed': 2660689,
#   'NewDeaths': 2,
#   'TotalDeaths': 20942,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'd8fd6731-538b-4502-ad71-364e703c8e7b',
#   'Country': 'Slovenia',
#   'CountryCode': 'SI',
#   'Slug': 'slovenia',
#   'NewConfirmed': 359,
#   'TotalConfirmed': 1321579,
#   'NewDeaths': 0,
#   'TotalDeaths': 7056,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'cf8c9236-b7cd-4aaa-bc85-a1d8280670ef',
#   'Country': 'Solomon Islands',
#   'CountryCode': 'SB',
#   'Slug': 'solomon-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24575,
#   'NewDeaths': 0,
#   'TotalDeaths': 153,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'be0251b4-a2a5-403e-988c-8960ffba999d',
#   'Country': 'Somalia',
#   'CountryCode': 'SO',
#   'Slug': 'somalia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27318,
#   'NewDeaths': 0,
#   'TotalDeaths': 1361,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '849a1256-7923-494b-9319-3e4c5a642815',
#   'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Slug': 'south-africa',
#   'NewConfirmed': 246,
#   'TotalConfirmed': 4055966,
#   'NewDeaths': 0,
#   'TotalDeaths': 102595,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '23c8926b-87e9-4829-8eea-30ad82f16b3d',
#   'Country': 'South Sudan',
#   'CountryCode': 'SS',
#   'Slug': 'south-sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 18368,
#   'NewDeaths': 0,
#   'TotalDeaths': 138,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '30a1c719-c3a3-427c-9308-460fb049b3c5',
#   'Country': 'Spain',
#   'CountryCode': 'ES',
#   'Slug': 'spain',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 13731478,
#   'NewDeaths': 0,
#   'TotalDeaths': 118434,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '686dee68-6cfa-452d-93ee-b999010da53f',
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Slug': 'sri-lanka',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 671989,
#   'NewDeaths': 0,
#   'TotalDeaths': 16828,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '5942b4dd-db64-45ac-9ad4-f6255b29ffa9',
#   'Country': 'Sudan',
#   'CountryCode': 'SD',
#   'Slug': 'sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 63742,
#   'NewDeaths': 0,
#   'TotalDeaths': 5001,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7a97d6cd-9110-4cb4-aaab-eaeabfebf075',
#   'Country': 'Suriname',
#   'CountryCode': 'SR',
#   'Slug': 'suriname',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 82020,
#   'NewDeaths': 0,
#   'TotalDeaths': 1398,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'b548c839-439c-4a81-b126-d55e44df891d',
#   'Country': 'Swaziland',
#   'CountryCode': 'SZ',
#   'Slug': 'swaziland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 74133,
#   'NewDeaths': 0,
#   'TotalDeaths': 1422,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '1b12bacf-922f-45cf-9beb-c6342c80c742',
#   'Country': 'Sweden',
#   'CountryCode': 'SE',
#   'Slug': 'sweden',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2693458,
#   'NewDeaths': 0,
#   'TotalDeaths': 23279,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '6eabace5-378f-47e2-b67e-e228fcf9830c',
#   'Country': 'Switzerland',
#   'CountryCode': 'CH',
#   'Slug': 'switzerland',
#   'NewConfirmed': 865,
#   'TotalConfirmed': 4407915,
#   'NewDeaths': 0,
#   'TotalDeaths': 14244,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '692dc2e8-e6d0-4739-8c58-70a5bd3b0231',
#   'Country': 'Syrian Arab Republic (Syria)',
#   'CountryCode': 'SY',
#   'Slug': 'syria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 57453,
#   'NewDeaths': 0,
#   'TotalDeaths': 3164,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '28d9e749-fd7a-4d31-89d2-de1ca4bd6292',
#   'Country': 'Taiwan, Republic of China',
#   'CountryCode': 'TW',
#   'Slug': 'taiwan',
#   'NewConfirmed': 32272,
#   'TotalConfirmed': 9537823,
#   'NewDeaths': 32,
#   'TotalDeaths': 16308,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f7c1bb66-1231-4f50-bc56-2db644c90d8c',
#   'Country': 'Tajikistan',
#   'CountryCode': 'TJ',
#   'Slug': 'tajikistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17786,
#   'NewDeaths': 0,
#   'TotalDeaths': 125,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '52ad98d6-431b-40a8-9dbd-537e96c7e7e1',
#   'Country': 'Tanzania, United Republic of',
#   'CountryCode': 'TZ',
#   'Slug': 'tanzania',
#   'NewConfirmed': 64,
#   'TotalConfirmed': 42664,
#   'NewDeaths': 0,
#   'TotalDeaths': 846,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'fb732cae-15ba-49b1-bb8f-894c439f5165',
#   'Country': 'Thailand',
#   'CountryCode': 'TH',
#   'Slug': 'thailand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4726984,
#   'NewDeaths': 0,
#   'TotalDeaths': 33865,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '7361f0a5-da64-4287-9ad8-d6f66f74e302',
#   'Country': 'Timor-Leste',
#   'CountryCode': 'TL',
#   'Slug': 'timor-leste',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 23415,
#   'NewDeaths': 0,
#   'TotalDeaths': 138,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '4142a951-3a19-483e-b3e5-5af15b5a0bc3',
#   'Country': 'Togo',
#   'CountryCode': 'TG',
#   'Slug': 'togo',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 39354,
#   'NewDeaths': 0,
#   'TotalDeaths': 290,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f8798e36-4993-4b61-acb4-cc0ba029538e',
#   'Country': 'Tonga',
#   'CountryCode': 'TO',
#   'Slug': 'tonga',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 16734,
#   'NewDeaths': 0,
#   'TotalDeaths': 13,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '02b18fae-f771-47f1-acfd-f65e038f26e8',
#   'Country': 'Trinidad and Tobago',
#   'CountryCode': 'TT',
#   'Slug': 'trinidad-and-tobago',
#   'NewConfirmed': 323,
#   'TotalConfirmed': 187908,
#   'NewDeaths': 7,
#   'TotalDeaths': 4326,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'df0713d6-3b6f-4c74-b4b7-ed85df1bbe94',
#   'Country': 'Tunisia',
#   'CountryCode': 'TN',
#   'Slug': 'tunisia',
#   'NewConfirmed': 78,
#   'TotalConfirmed': 1150356,
#   'NewDeaths': 6,
#   'TotalDeaths': 29308,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '6871de8a-c4c3-44ae-9134-fd5c36b700cd',
#   'Country': 'Turkey',
#   'CountryCode': 'TR',
#   'Slug': 'turkey',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17042722,
#   'NewDeaths': 0,
#   'TotalDeaths': 101492,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'ce0a0688-180f-4e43-83d0-c9d291647547',
#   'Country': 'Tuvalu',
#   'CountryCode': 'TV',
#   'Slug': 'tuvalu',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2805,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '040f1722-0c2a-4d3a-91ce-313c0204ffd1',
#   'Country': 'Uganda',
#   'CountryCode': 'UG',
#   'Slug': 'uganda',
#   'NewConfirmed': 72,
#   'TotalConfirmed': 170400,
#   'NewDeaths': 0,
#   'TotalDeaths': 3630,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '6ae61924-ad03-48e4-a328-5aa93f4bb45a',
#   'Country': 'Ukraine',
#   'CountryCode': 'UA',
#   'Slug': 'ukraine',
#   'NewConfirmed': 51,
#   'TotalConfirmed': 5679371,
#   'NewDeaths': 1,
#   'TotalDeaths': 118974,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '4711f783-1a16-423a-8a36-a86b17b80ebb',
#   'Country': 'United Arab Emirates',
#   'CountryCode': 'AE',
#   'Slug': 'united-arab-emirates',
#   'NewConfirmed': 64,
#   'TotalConfirmed': 1049409,
#   'NewDeaths': 0,
#   'TotalDeaths': 2348,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '245f4a6e-96a6-4591-8edb-dd6ac76f8fbe',
#   'Country': 'United Kingdom',
#   'CountryCode': 'GB',
#   'Slug': 'united-kingdom',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24507298,
#   'NewDeaths': 0,
#   'TotalDeaths': 218028,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'f1f0e127-3b86-4e15-9b16-239f45355d4a',
#   'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Slug': 'united-states',
#   'NewConfirmed': 35040,
#   'TotalConfirmed': 102345676,
#   'NewDeaths': 627,
#   'TotalDeaths': 1108482,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '3f48e6e5-86b1-4b26-9f32-e415c5888a0a',
#   'Country': 'Uruguay',
#   'CountryCode': 'UY',
#   'Slug': 'uruguay',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1032710,
#   'NewDeaths': 0,
#   'TotalDeaths': 7609,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'db7aa5b7-dae7-4b8b-8bbd-7475c6ace590',
#   'Country': 'Uzbekistan',
#   'CountryCode': 'UZ',
#   'Slug': 'uzbekistan',
#   'NewConfirmed': 4,
#   'TotalConfirmed': 250567,
#   'NewDeaths': 0,
#   'TotalDeaths': 1637,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'c73e59d4-4038-4684-8ea8-cd100a6a00ca',
#   'Country': 'Vanuatu',
#   'CountryCode': 'VU',
#   'Slug': 'vanuatu',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 12014,
#   'NewDeaths': 0,
#   'TotalDeaths': 14,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '58e45c45-5ef3-4f48-909a-b48e7444ce0d',
#   'Country': 'Venezuela (Bolivarian Republic)',
#   'CountryCode': 'VE',
#   'Slug': 'venezuela',
#   'NewConfirmed': 45,
#   'TotalConfirmed': 551587,
#   'NewDeaths': 0,
#   'TotalDeaths': 5845,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '2272e047-0c9c-4361-939b-edb38d462ee6',
#   'Country': 'Viet Nam',
#   'CountryCode': 'VN',
#   'Slug': 'vietnam',
#   'NewConfirmed': 36,
#   'TotalConfirmed': 11526497,
#   'NewDeaths': 0,
#   'TotalDeaths': 43186,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': 'bf4372ca-1d2d-402e-a2d5-7f10513f7d61',
#   'Country': 'Yemen',
#   'CountryCode': 'YE',
#   'Slug': 'yemen',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11945,
#   'NewDeaths': 0,
#   'TotalDeaths': 2159,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '371987de-724c-4379-bda5-00bb635247e8',
#   'Country': 'Zambia',
#   'CountryCode': 'ZM',
#   'Slug': 'zambia',
#   'NewConfirmed': 181,
#   'TotalConfirmed': 340763,
#   'NewDeaths': 1,
#   'TotalDeaths': 4047,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}},
#  {'ID': '1265b0ad-b2b0-4727-850c-48be94b0b777',
#   'Country': 'Zimbabwe',
#   'CountryCode': 'ZW',
#   'Slug': 'zimbabwe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 261606,
#   'NewDeaths': 0,
#   'TotalDeaths': 5652,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-02T12:39:30.535Z',
#   'Premium': {}}]

# %%
type(json['Countries'])
# Out:
# list

# %%
df = pd.DataFrame(json['Countries'])
df.head(10)
# Out:
#                                      ID              Country CountryCode  \
# 0  d71c39e7-76dd-43d3-90c9-39b7298054f9          Afghanistan          AF
# 1  e69188a8-3c0d-4414-8805-0963d08b81c1              Albania          AL
# 2  757ae08f-23d0-4c39-bbf2-f5693b60ce1d              Algeria          DZ
# 3  fab05bf5-d9e5-4e71-8c45-3f90ffcfd12d              Andorra          AD
# 4  e3c286b7-3023-43e1-a1bf-02102dc3af1f               Angola          AO
# 5  2a859bbd-5fb3-4a3f-9c3f-4dcc857ef273           Antarctica          AQ
# 6  4c6b31b3-9b8d-4f86-8611-c9b06fe5a250  Antigua and Barbuda          AG
# 7  f4c54b9f-b940-4e6d-b43b-6c438cfa2466            Argentina          AR
# 8  f3490240-982c-44f2-9f8d-acf61fc95d99              Armenia          AM
# 9  2641ec32-553e-4d42-a5ec-2225d93e4fe6            Australia          AU
#
#                   Slug  NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  \
# 0          afghanistan            43          208545          3         7882
# 1              albania            10          334167          0         3596
# 2              algeria             2          271378          0         6881
# 3              andorra             0           47839          0          165
# 4               angola             0          105184          0         1931
# 5           antarctica             0              11          0            0
# 6  antigua-and-barbuda             0            9106          0          146
# 7            argentina             0        10037135          0       130421
# 8              armenia             0          446008          0         8717
# 9            australia             0        11295446          0        18615
#
#    NewRecovered  TotalRecovered                      Date Premium
# 0             0               0  2023-02-02T12:39:30.535Z      {}
# 1             0               0  2023-02-02T12:39:30.535Z      {}
# 2             0               0  2023-02-02T12:39:30.535Z      {}
# 3             0               0  2023-02-02T12:39:30.535Z      {}
# 4             0               0  2023-02-02T12:39:30.535Z      {}
# 5             0               0  2023-02-02T12:39:30.535Z      {}
# 6             0               0  2023-02-02T12:39:30.535Z      {}
# 7             0               0  2023-02-02T12:39:30.535Z      {}
# 8             0               0  2023-02-02T12:39:30.535Z      {}
# 9             0               0  2023-02-02T12:39:30.535Z      {}

# %%
df.shape
# Out:
# (197, 12)
